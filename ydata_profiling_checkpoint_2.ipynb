# %% [markdown]
# <a href="https://colab.research.google.com/github/ochouchene/-Data-Gathering-with-API-/blob/main/ydata_profiling_checkpoint_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('Tunisair_flights_dataset.csv')

print(df.head())

print(df.info())

print(df.isnull().sum())

print(df.describe())
# Out:
#   Filght_date Flight_ID Departure point Arrival point  \
# 0  2016-01-03  TU 0712              CMN           TUN
# 1  2016-01-13  TU 0757              MXP           TUN
# 2  2016-01-16  TU 0214              TUN           IST
# 3  2016-01-17  TU 0480              DJE           NTE
# 4  2016-01-17  TU 0338              TUN           ALG
#
#   Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0      2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1      2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# 2      2016-01-16 04:10:00    2016-01-16 06.45.00    ATA     TU 32AIMN
# 3      2016-01-17 14:10:00    2016-01-17 17.00.00    ATA     TU 736IOK
# 4      2016-01-17 14:30:00    2016-01-17 15.50.00    ATA     TU 320IMU
#
#    Arrival delay
# 0          260.0
# 1           20.0
# 2            0.0
# 3            0.0
# 4           22.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96681 entries, 0 to 96680
# ...

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title="Tunisair_flights_dataset.csv", explorative=True)
profile.to_widgets()
profile.to_file("Tunisair_flights_dataset.csv")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/profile_report.py:535: UserWarning: Ipywidgets is not yet fully supported on Google Colab (https://github.com/googlecolab/colabtools/issues/60).As an alternative, you can use the HTML report. See the documentation for more information.
#   warnings.warn(
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-371422654.py in <cell line: 0>()
#       2
# ...

# %%
profile.to_file("Tunisair_flights_dataset.csv")
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/profile_report.py:386: UserWarning: Extension .csv not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)]
    print(f"Column '{col}' has {len(outliers)} outliers")
# Out:
# Column 'Arrival delay' has 12705 outliers

# %% [markdown]
# Dataset size:

# %%
rows, cols = df.shape

# Print using f-string
print(f"The dataset has {rows} rows and {cols} columns.")
# Out:
# The dataset has 96681 rows and 9 columns.

# %% [markdown]
# Missing values per column:

# %%
missing = df.isnull().sum()
print(missing[missing > 0])
# Out:
# Departure point             1
# Arrival point               1
# Scheduled_departure_time    1
# Scheduled_arrival_time      1
# STATUS                      1
# Aircraft_code               1
# Arrival delay               1
# dtype: int64

# %%
Data types of columns:

# %%
print(df.dtypes)
# Out:
# Filght_date                  object
# Flight_ID                    object
# Departure point              object
# Arrival point                object
# Scheduled_departure_time     object
# Scheduled_arrival_time       object
# STATUS                       object
# Aircraft_code                object
# Arrival delay               float64
# dtype: object

# %% [markdown]
# Descriptive statistics for numeric columns:

# %%
print(df.describe())
# Out:
#        Arrival delay
# count   96680.000000
# mean       49.736378
# std       115.677228
# min         0.000000
# 25%         0.000000
# 50%        15.000000
# 75%        45.000000
# max      3451.000000
